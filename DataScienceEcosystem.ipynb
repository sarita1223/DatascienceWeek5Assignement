# %% [markdown]
# # H1: Data Science Tools and Ecosystem

# %% [markdown]
# ![2_title.png](attachment:bbea6472-18b4-496d-b60c-f426b6e17163.png)

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# ordered list commonly used languages for data science.
#
# 1. Python
# 2. R
# 3. Scala

# %% [markdown]
# ![4-dslanguages.png](attachment:d108212d-cec6-4463-8422-df34bc0d094c.png)

# %% [markdown]
# data science libraries:
#
# 1. Pandas
# 2. Numpy
# 3. Sklearn

# %% [markdown]
# ![5-libraries.png](attachment:d3c69928-0cd7-401f-804b-ec8e30ec4a5d.png)

# %% [markdown]
# |Data Science Tools|
# |------------------|
# | Matlabh |
# | Apache Spark |
# | Jupyter |

# %% [markdown]
# ![6-dstools.png](attachment:e558a552-5058-4557-b242-7934c3fc0b25.png)

# %% [markdown]
# ### H3 : Below are a few examples of evaluating arithmetic expressions in Python

# %% [markdown]
# ![7-introarithmetic.png](attachment:9665dff1-3e39-4acf-8acb-f9adbb1afa48.png)

# %%
#This a simple arithmetic expression to multiply then add integers
x=(3*4)+5
print(x)
# Out:
# 17

# %% [markdown]
# ![8-multiplyandaddintegers.png](attachment:880be676-fadf-4a5e-ad02-6c5d6a76ac30.png)

# %%
# This will convert 200 minutes to hours by diving by 60
x=200/60
print(x)
# Out:
# 3.3333333333333335

# %% [markdown]
# ![9-hourstominutes.png](attachment:19dc4207-2440-4dbf-85f9-961ae51e556c.png)

# %% [markdown]
# ***Bold Objectives:.***

# %% [markdown]
# - Python
# - R
# - Scala

# %% [markdown]
# ![10-objectives.png](attachment:bc633881-b6a4-4305-a38e-15f257fd81fe.png)

# %% [markdown]
# ## Author: Alaoui Sara
